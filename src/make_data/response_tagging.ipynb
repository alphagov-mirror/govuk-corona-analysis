# %%
import pandas as pd
from openpyxl.workbook import Workbook
import re

data_uiszendesk = pd.read_excel(io = '../../data/GAUISZ_Draft_Report_20200417to20200419.xlsx',  
                                col_index = None)
data_uiszendesk
# Out:
#               created_at  source  \
# 0    2020-04-16 23:00:33     UIS
# 1    2020-04-16 23:00:33     UIS
# 2    2020-04-16 23:00:33     UIS
# 3    2020-04-16 23:10:32     UIS
# 4    2020-04-16 23:26:28     UIS
# ...                  ...     ...
# 2523 2020-04-19 22:05:58     UIS
# 2524 2020-04-19 22:08:18  Ticket
# 2525 2020-04-19 22:12:49  Ticket
# 2526 2020-04-19 22:43:02     UIS
# 2527 2020-04-19 22:55:33  Ticket
#
#                                                     URL            Q1  \
# 0     www.gov.uk//guidance/claim-a-grant-through-the...  Professional
# 1     www.gov.uk//guidance/coronavirus-covid-19-what...  Professional
# 2     www.gov.uk//guidance/coronavirus-covid-19-what...  Professional
# 3                               www.gov.uk//coronavirus      Personal
# 4                               www.gov.uk//coronavirus      Personal
# ...                                                 ...           ...
# 2523                            www.gov.uk//coronavirus  Professional
# 2524  www.gov.uk/government/publications/coronavirus...           NaN
# 2525  www.gov.uk/government/publications/coronavirus...           NaN
# 2526       www.gov.uk//coronavirus-extremely-vulnerable      Personal
# 2527  www.gov.uk/guidance/work-out-80-of-your-employ...           NaN
#
#                         Q2                                  Q3_or_Description  \
# 0     Health and wellbeing  I need to apply for UC because I m self employ...
# 1     Health and wellbeing  I need to apply for UC because I m self employ...
# 2     Health and wellbeing  I need to apply for UC because I m self employ...
# 3                        -  I am an Australian citizen here in the UK\n(Du...
# 4                        -  Wanted to complain about coronavirus lockdown ...
# ...                    ...                                                ...
# 2523                 Nurse  To find out if you can get an isolation note o...
# 2524                   NaN  url: https://www.gov.uk/government/publication...
# 2525                   NaN  [Requester]\nmr [PERSON_NAME] <[EMAIL_ADDRESS]...
# 2526                     -  I live on my own find it very hard. To do the ...
# 2527                   NaN  url: https://www.gov.uk/guidance/work-out-80-o...
#
#                       Q4                                  Q5   Q6  \
# 0                     No                Not at all satisfied  Yes
# 1                     No                Not at all satisfied  Yes
# 2                     No                Not at all satisfied  Yes
# 3                     No                        Dissatisfied  Yes
# 4                     No                Not at all satisfied  Yes
# ...                  ...                                 ...  ...
# 2523                  No  Neither satisfied nor dissatisfied   No
# 2524                 NaN                                 NaN  NaN
# 2525                 NaN                                 NaN  NaN
# 2526  Not sure / Not yet                Not at all satisfied   No
# 2527                 NaN                                 NaN  NaN
#
#                                                Q7  \
# 0                 Other pages on this site, my MP
# 1                 Other pages on this site, my MP
# 2                 Other pages on this site, my MP
# 3     Australian embassy \n\nNothing to help me ?
# 4           Tried local police authority website
# ...                                           ...
# 2523                               I wil call 111
# 2524                                          NaN
# 2525                                          NaN
# 2526                                            -
# 2527                                          NaN
#
#                                                      Q8
# 0     Your UC application page has kicked me out 17 ...
# 1     Your UC application page has kicked me out 17 ...
# 2     Your UC application page has kicked me out 17 ...
# 3     Just please somebody advise me !\n\nThankyou v...
# 4     This government has got what it has allways wa...
# ...                                                 ...
# 2523  Please make option for people who are positive...
# 2524                                                NaN
# 2525                                                NaN
# 2526                                                  -
# 2527                                                NaN
#
# [2528 rows x 11 columns]

# %%
# remove everything 'referrer'-related
data_uiszendesk['Q3_or_Description_prepped'] = data_uiszendesk['Q3_or_Description'].str.split('\[Referrer\]|referrer\:').str[0]
# remove everything 'user_agent'-related
data_uiszendesk['Q3_or_Description_prepped'] = data_uiszendesk['Q3_or_Description_prepped'].str.split('\[User agent\]|user_agent\:').str[0]
# remove everything 'javascript_enable'-related
data_uiszendesk['Q3_or_Description_prepped'] = data_uiszendesk['Q3_or_Description_prepped'].str.split('\[JavaScript Enabled\]|javascript_enabled\:').str[0]

# %%
# remove everything and including '[Details]'
data_uiszendesk['Q3_or_Description_prepped'] = data_uiszendesk['Q3_or_Description_prepped'].str.split('\[Details\]').str[-1]

# %%
data_uiszendesk.to_excel("../../data/test.xlsx")
